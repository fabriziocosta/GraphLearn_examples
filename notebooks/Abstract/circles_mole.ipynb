# %% [markdown]
# ## circle abstraction for chemical structure graphs
# In this notebook I show how to use Graphlearn with abstract graphs to generate molecules with an abstraction
# that deals with circular motives.

# %% [markdown]
# ### initialising

# %%
# %load_ext autoreload
# %autoreload 2
from eden.util import configure_logging
import logging
debug=True

configure_logging(logging.getLogger(),verbosity=1+debug)
# %matplotlib inline

# %% [markdown]
# ### get_graphs will provide data( networkx graphs )

# %%
from eden.converter.graph.gspan import gspan_to_eden
from itertools import islice

def get_graphs(dataset_fname='../toolsdata/bursi.pos.gspan', size=100):
    return  islice(gspan_to_eden(dataset_fname),size)

# %% [markdown]
# ## I demonstrate what an abstract graph looks like

# %%
from graphlearn.utils import draw
import graphlearn.abstract_graphs.mole.circletransform as mole
import graphlearn.abstract_graphs.minordecompose as decompose
from graphlearn.graphlearn import Sampler as GLS
from eden.graph import Vectorizer

# get a graph and prepare it
graphs=get_graphs()
g=graphs.next()
g=vectorizer._graph_preprocessing(g)
make_decomposer = lambda x,y: decompose.MinorDecomposer(x,y,
                       include_base=False,
                       base_thickness_list=[2])
#the preprocessor makes the abstraction, wrapper provides convenient format for drawing
preproc=mole.GraphTransformerCircles()
graph_wrapper=make_decomposer(preproc.vectorizer,preproc.wrap(g))
graph=graph_wrapper.pre_vectorizer_graph(nested=True)


# draw 
draw.graphlearn(graph,size=10, abstract_color='red', contract=True,ignore_for_layout='nesting')

# %% [markdown]
# ## Here we see different views on a graph, provided by the wrapper,
#
# for the sampling process CIPs need to be extracted.
# here we see this mechanism.

# %%
from graphlearn.utils import draw
from graphlearn.graphlearn import Sampler as GLS
from eden.graph import Vectorizer



print 'DEMONSTRATING WRAPPER'
graphs=get_graphs()
for i in range(1):
    print 'grammar example %d' % i
    g=graphs.next()
    gm=make_decomposer(vectorizer,preproc.wrap(g))
    draw.graphlearn([gm.pre_vectorizer_graph(nested=True),gm.abstract_graph(),gm.base_graph()], 
                    size = 15,
                    vertex_label = 'label',
                    contract=False)

    
print 'DEMONSTRATING EXTRACTION'  
radius_list=[0,2]
thickness_list=[2,4]
base_thickness_list=[2]
argz=(gm,radius_list,thickness_list,Vectorizer(),2**20-1,lambda x,y:True, base_thickness_list)

cips=gm.all_core_interface_pairs(thickness_list=[2],radius_list=[0,1],hash_bitmask=2**20-1)
draw.graphlearn(cips[0][0].graph, contract=False)
draw.graphlearn(cips[0][1].graph, contract=False)
# Out:
# DEMONSTRATING WRAPPER
# grammar example 0
# DEMONSTRATING EXTRACTION

# %% [markdown]
# ## here we prepare a sampler and then take a closer look at the generated grammar.

# %%
# %%time
from graphlearn.graphlearn import Sampler as GLS
graphs = get_graphs(size=200)
sampler=GLS(radius_list=[0,1],
            thickness_list=[1], 
            min_cip_count=2, 
            min_interface_count=2, 
            decomposer=make_decomposer,
            graphtransformer=mole.GraphTransformerCircles())
sampler.fit(graphs,grammar_n_jobs=1,grammar_batch_size=1)
# Out:
# #instances: 200  #interfaces: 51   #cores: 73   #core-interface-pairs: 226
# CPU times: user 6.36 s, sys: 16 ms, total: 6.38 s
# Wall time: 6.37 s

# %%
#show congruent cips in grammar
draw.draw_grammar(sampler.lsgg.productions,n_productions=5,n_graphs_per_production=5,
                     n_graphs_per_line=5, size=9, contract=False,
                     colormap='Paired', invert_colormap=False,node_border=1,
                     vertex_alpha=0.6, edge_alpha=0.5, node_size=450, abstract_interface=True)
# Out:
# interface id: 553552 [23 options]
# interface id: 646356 [16 options]
# interface id: 735458 [15 options]
# interface id: 151696 [15 options]
# interface id: 538594 [14 options]

# %% [markdown]
# ## Molecule sampling

# %%
# %%time
import graphlearn.utils.draw as draw
from graphlearn.utils import openbabel
import graphlearn.abstract_graphs.mole.circletransform as mole
import itertools

# parameters
graphs = get_graphs()
id_start=15
id_end=id_start+9
graphs = itertools.islice(graphs,id_start,id_end)
n_steps=100


#sampling
graphs = sampler.sample(graphs,
                        n_samples=5,
                        batch_size=1,
                        n_steps=n_steps,
                        n_jobs=1,
                        quick_skip_orig_cip=True,
                        probabilistic_core_choice=False,
                        burnin=0,
                        improving_threshold=0.5,
                        max_size_diff=10,
                        select_cip_max_tries=100,
                        keep_duplicates=True,
                        include_seed=True)

 
scores=[]
ids=range(id_start,id_end)
for i,path_graphs in enumerate(graphs):
    # path_graphs is a list of 'sampled' graphs for 1 run 
    print 'Graph id: %d'%(ids[i])
    #save score
    scores.append(sampler.monitors[i].sampling_info['score_history'])
    # draw
    if debug:
        draw.graphlearn(path_graphs,
                           n_graphs_per_line=5, size=10, 
                           colormap='Paired', invert_colormap=False,node_border=0.5, vertex_color='color_level',
                           vertex_alpha=0.5, edge_alpha=0.7, node_size=450,edge_label='label'  )
    else:
        openbabel.draw(path_graphs)
# Out:
# preprocessing grammar
# adding core size lookup to lsgg
# _sample_notes: None
# accept_min_similarity: 0.0
# accept_static_penalty: 0.0
# batch_size: 1
#     burnin: 0
# decomposer_generator: <function <lambda> at 0x7f7ad8dcf050>
# estimatorobject: <graphlearn.estimate.OneClassEstimator instance at 0x7f7adb8cbcf8>
# feasibility_checker: <graphlearn.feasibility.FeasibilityChecker instance at 0x7f7adb8cbd40>
# graphtransformer: <graphlearn.abstract_graphs.mole.circletransform.GraphTransformerCircles object at 0x7f7ad9352450>
# hash_bitmask: 1048575
# improving_linear_start: 0
# improving_penalty_per_step: 0.02
# improving_threshold: 50
# include_seed: True
# keep_duplicates: True
#       lsgg: <graphlearn.localsubstitutablegraphgrammar.LocalSubstitutableGraphGrammar object at 0x7f7ad36d7990>
# max_core_size_diff: 20
# maxbacktrack: 0
#    monitor: False
#   monitors: []
#     n_jobs: 1
#    n_steps: 100
#       nbit: 20
# node_entity_check: <function <lambda> at 0x7f7adb8d2320>
# postprocessor: <graphlearn.transform.PostProcessor object at 0x7f7adb8c5f90>
# probabilistic_core_choice: False
# proposal_probability: False
# quick_skip_orig_cip: True
# radius_list: [0, 2]
# random_state: None
# sample_path: None
# sampling_interval: 20
# score_core_choice: False
# select_cip_max_tries: 100
# similarity: -1
#       step: None
# target_orig_cip: False
# thickness_list: [2]
# vectorizer:                   bitmask: 1048575                complexity: 3                         d: 6     discretization_models: {}              feature_size: 1048577                fit_status: None       inner_normalization: True                key_entity: entity            key_importance: importance                 key_label: label               key_nesting: nesting        key_original_label: original_label                key_weight: weight                label_size: 1                     min_d: 0                     min_n: 2                     min_r: 0                         n: 1                      name: Vectorizer                     nbits: 20             normalization: True                         r: 6
# _propose_graph: iteration 0 ; core 0 of 5 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 1 ; core 0 of 15 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 2 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 3 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 4 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 5 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 6 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 7 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 8 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 9 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 10 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 11 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 12 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 13 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 14 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 15 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 16 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 17 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 18 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 19 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 20 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 21 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 22 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 23 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 24 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 25 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 26 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 27 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 28 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 29 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 30 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 31 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 32 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 33 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 34 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 35 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 36 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 37 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 38 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 39 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 40 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 41 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 42 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 43 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 44 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 45 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 46 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 47 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 48 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 49 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 50 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 51 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 52 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 53 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 54 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 55 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 56 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 57 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 58 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 59 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 60 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 61 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 62 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 63 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 64 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 65 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 66 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 67 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 68 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 69 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 70 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 71 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 72 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 73 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 74 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 75 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 76 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 77 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 78 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 79 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 80 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 81 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 82 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 83 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 84 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 85 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 86 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 87 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 88 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 89 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 90 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 91 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 92 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 93 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 94 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 95 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 96 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 97 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 98 ; core 0 of 15 ; original_cips tried  0 ; size 54
# _propose_graph: iteration 99 ; core 0 of 15 ; original_cips tried  0 ; size 54
# Graph id: 15
# _propose_graph: iteration 0 ; core 0 of 1 ; original_cips tried  0 ; size 29
# _propose_graph: iteration 1 ; core 0 of 1 ; original_cips tried  0 ; size 29
# _propose_graph: iteration 2 ; core 0 of 1 ; original_cips tried  0 ; size 29
# _propose_graph: iteration 3 ; core 0 of 1 ; original_cips tried  0 ; size 29
# _propose_graph: iteration 4 ; core 0 of 1 ; original_cips tried  0 ; size 29
# _propose_graph: iteration 5 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 6 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 7 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 8 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 9 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 10 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 11 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 12 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 13 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 14 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 15 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 16 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 17 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 18 ; core 0 of 5 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 19 ; core 0 of 1 ; original_cips tried  0 ; size 33
# select_cip_for_substitution failed because no suiting interface was found,                 extract failed 100 times; cip found but unacceptable:91
# propose failed.. usualy the problem is propose_single_cip
# Traceback (most recent call last):
#   File "/home/ikea/GraphLearn/graphlearn/graphlearn.py", line 426, in _sample
#     candidate_graph_manager = self._propose(graph_manager)
#   File "/home/ikea/GraphLearn/graphlearn/graphlearn.py", line 638, in _propose
#     raise Exception("propose failed.. usualy the problem is propose_single_cip")
# Exception: propose failed.. usualy the problem is propose_single_cip
#
# _sample stopped at 20 out of 100 n_steps
# Graph id: 16
# _propose_graph: iteration 0 ; core 0 of 15 ; original_cips tried  0 ; size 35
# _propose_graph: iteration
# _propose_graph: iteration 70 ; core 0 of 22 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 71 ; core 0 of 4 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 72 ; core 0 of 22 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 73 ; core 0 of 3 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 74 ; core 0 of 22 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 75 ; core 0 of 5 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 76 ; core 0 of 15 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 77 ; core 0 of 3 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 78 ; core 0 of 15 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 79 ; core 0 of 2 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 80 ; core 0 of 3 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 81 ; core 0 of 15 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 82 ; core 0 of 1 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 83 ; core 0 of 4 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 84 ; core 0 of 5 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 85 ; core 0 of 15 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 86 ; core 0 of 3 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 87 ; core 0 of 3 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 88 ; core 0 of 15 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 89 ; core 0 of 15 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 90 ; core 0 of 15 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 91 ; core 0 of 3 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 92 ; core 0 of 15 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 93 ; core 0 of 15 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 94 ; core 0 of 15 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 95 ; core 0 of 15 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 96 ; core 0 of 15 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 97 ; core 0 of 15 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 98 ; core 0 of 3 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 99 ; core 0 of 3 ; original_cips tried  0 ; size 40
# Graph id: 17
# _propose_graph: iteration 0 ; core 0 of 15 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 1 ; core 0 of 1 ; original_cips tried  0 ; size 39
# _propose_graph: iteration 2 ; core 0 of 13 ; original_cips tried  0 ; size 39
# _propose_graph: iteration 3 ; core 0 of 1 ; original_cips tried  0 ; size 39
# _propose_graph: iteration 4 ; core 0 of 15 ; original_cips tried  0 ; size 39
# _propose_graph: iteration 5 ; core 0 of 2 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 6 ; core 0 of 14 ; original_cips tried  0 ; size 24
# _propose_graph: iteration 7 ; core 0 of 14 ; original_cips tried  0 ; size 24
# _propose_graph: iteration 8 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 9 ; core 0 of 15 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 10 ; core 0 of 15 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 11 ; core 0 of 22 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 12 ; core 0 of 15 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 13 ; core 0 of 3 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 14 ; core 0 of 2 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 15 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 16 ; core 0 of 22 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 17 ; core 0 of 22 ; original_cips tried  0 ; size 23
# _propose_graph: iteration 18 ; core 0 of 22 ; original_cips tried  0 ; size 23
# _propose_graph: iteration 19 ; core 0 of 14 ; original_cips tried  0 ; size 38
# _propose_graph: iteration 20 ; core 0 of 1 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 21 ; core 0 of 22 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 22 ; core 0 of 22 ; original_cips tried  0 ; size 36
# _propose_graph: iteration 23 ; core 0 of 2 ; original_cips tried  1 ; size 53
# _propose_graph: iteration 24 ; core 0 of 14 ; original_cips tried  0 ; size 53
# _propose_graph: iteration
; original_cips tried  0 ; size 98
# _propose_graph: iteration 24 ; core 0 of 1 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 25 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 26 ; core 0 of 15 ; original_cips tried  0 ; size 100
# _propose_graph: iteration 27 ; core 0 of 2 ; original_cips tried  0 ; size 100
# _propose_graph: iteration 28 ; core 0 of 3 ; original_cips tried  0 ; size 100
# _propose_graph: iteration 29 ; core 0 of 22 ; original_cips tried  0 ; size 100
# _propose_graph: iteration 30 ; core 0 of 2 ; original_cips tried  0 ; size 100
# _propose_graph: iteration 31 ; core 0 of 3 ; original_cips tried  0 ; size 100
# _propose_graph: iteration 32 ; core 0 of 3 ; original_cips tried  0 ; size 102
# _propose_graph: iteration 33 ; core 0 of 3 ; original_cips tried  0 ; size 102
# _propose_graph: iteration 34 ; core 0 of 2 ; original_cips tried  0 ; size 102
# _propose_graph: iteration 35 ; core 0 of 5 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 36 ; core 0 of 15 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 37 ; core 0 of 3 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 38 ; core 0 of 15 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 39 ; core 0 of 15 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 40 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 41 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 42 ; core 0 of 5 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 43 ; core 0 of 15 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 44 ; core 0 of 3 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 45 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 46 ; core 0 of 5 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 47 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 48 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 49 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 50 ; core 0 of 5 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 51 ; core 0 of 15 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 52 ; core 0 of 13 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 53 ; core 0 of 2 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 54 ; core 0 of 14 ; original_cips tried  0 ; size 98
# _propose_graph: iteration 55 ; core 0 of 6 ; original_cips tried  0 ; size 94
# _propose_graph: iteration 56 ; core 0 of 15 ; original_cips tried  0 ; size 94
# _propose_graph: iteration 57 ; core 0 of 22 ; original_cips tried  0 ; size 94
# _propose_graph: iteration 58 ; core 0 of 15 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 59 ; core 0 of 15 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 60 ; core 0 of 2 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 61 ; core 0 of 2 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 62 ; core 0 of 2 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 63 ; core 0 of 2 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 64 ; core 0 of 15 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 65 ; core 0 of 22 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 66 ; core 0 of 2 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 67 ; core 0 of 2 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 68 ; core 0 of 22 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 69 ; core 0 of 15 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 70 ; core 0 of 15 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 71 ; core 0 of 15 ; original_cips tried  0 ; size 92
# _propose_graph: iteration 72 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 73 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 74 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 75 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 76 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 77 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 78 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 79 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 80 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 81 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 82 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 83 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 84 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 85 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 86 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 87 ; core 0 of 22 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 88 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 89 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 90 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 91 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 92 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 93 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 94 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 95 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 96 ; core 0 of 2 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 97 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 98 ; core 0 of 15 ; original_cips tried  0 ; size 90
# _propose_graph: iteration 99 ; core 0 of 2 ; original_cips tried  0 ; size 90
# Graph id: 20
# _propose_graph: iteration 0 ; core 0 of 2 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 1 ; core 0 of 15 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 2 ; core 0 of 22 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 3 ; core 0 of 2 ; original_cips tried  0 ; size 24
# _propose_graph: iteration 4 ; core 0 of 2 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 5 ; core 0 of 22 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 6 ; core 0 of 1 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 7 ; core 0 of 22 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 8 ; core 0 of 2 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 9 ; core 0 of 14 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 10 ; core 0 of 14 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 11 ; core 0 of 13 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 12 ; core 0 of 13 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 13 ; core 0 of 1 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 14 ; core 0 of 1 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 15 ; core 0 of 14 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 16 ; core 0 of 2 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 17 ; core 0 of 1 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 18 ; core 0 of 14 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 19 ; core 0 of 22 ; original_cips tried  0 ; size 36
# _propose_graph: iteration 20 ; core 0 of 13 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 21 ; core 0 of 22 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 22 ; core 0 of 14 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 23 ; core 0 of 13 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 24 ; core 0 of 13 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 25 ; core 0 of 22 ; original_cips tried  0 ; size 48
# _propose_graph: iteration 26 ; core 0 of 3 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 27 ; core 0 of 14 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 28 ; core 0 of 14 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 29 ; core 0 of 22 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 30 ; core 0 of 1 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 31 ; core 0 of 4 ; original_cips tried  0 ; size 46
# _propose_graph: iteration 32 ; core 0 of 3 ; original_cips tried  0 ; size 50
# _propose_graph: iteration 33 ; core 0 of 14 ; original_cips tried  0 ; size 50
# _propose_graph: iteration 34 ; core 0 of 3 ; original_cips tried  0 ; size 57
# _propose_graph: iteration 35 ; core 0 of 22 ; original_cips tried  0 ; size 57
# _propose_graph: iteration 36 ; core 0 of 3 ; original_cips tried  0 ; size 57
# _propose_graph: iteration 37 ; core 0 of 6 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 38 ; core 0 of 14 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 39 ; core 0 of 13 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 40 ; core 0 of 14 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 41 ; core 0 of 1 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 42 ; core 0 of 14 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 43 ; core 0 of 2 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 44 ; core 0 of 2 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 45 ; core 0 of 22 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 46 ; core 0 of 13 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 47 ; core 0 of 3 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 48 ; core 0 of 2 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 49 ; core 0 of 4 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 50 ; core 0 of 1 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 51 ; core 0 of 14 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 52 ; core 0 of 1 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 53 ; core 0 of 3 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 54 ; core 0 of 2 ; original_cips tried  0 ; size 53
# _propose_graph: iteration 55 ; core 0 of 5 ; original_cips tried  0 ; size 53
# ...
# _propose_graph: iteration 98 ; core 0 of 13 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 99 ; core 0 of 13 ; original_cips tried  0 ; size 43
# Graph id: 21
# _propose_graph: iteration 0 ; core 0 of 5 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 1 ; core 0 of 2 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 2 ; core 0 of 3 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 3 ; core 0 of 5 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 4 ; core 0 of 3 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 5 ; core 0 of 3 ; original_cips tried  0 ; size 42
# _propose_graph: iteration 6 ; core 0 of 1 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 7 ; core 0 of 1 ; original_cips tried  0 ; size 36
# _propose_graph: iteration 8 ; core 0 of 3 ; original_cips tried  0 ; size 34
# _propose_graph: iteration 9 ; core 0 of 1 ; original_cips tried  0 ; size 34
# _propose_graph: iteration 10 ; core 0 of 4 ; original_cips tried  0 ; size 36
# _propose_graph: iteration 11 ; core 0 of 22 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 12 ; core 0 of 22 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 13 ; core 0 of 1 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 14 ; core 0 of 22 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 15 ; core 0 of 3 ; original_cips tried  0 ; size 41
# _propose_graph: iteration 16 ; core 0 of 1 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 17 ; core 0 of 1 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 18 ; core 0 of 4 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 19 ; core 0 of 4 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 20 ; core 0 of 14 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 21 ; core 0 of 3 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 22 ; core 0 of 22 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 23 ; core 0 of 3 ; original_cips tried  1 ; size 51
# _propose_graph: iteration 24 ; core 0 of 3 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 25 ; core 0 of 3 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 26 ; core 0 of 3 ; original_cips tried  0 ; size 51
# _propose_graph: iteration 27 ; core 0 of 3 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 28 ; core 0 of 1 ; original_cips tried  0 ; size 45
# _propose_graph: iteration 29 ; core 0 of 22 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 30 ; core 0 of 4 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 31 ; core 0 of 1 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 32 ; core 0 of 4 ; original_cips tried  0 ; size 49
# _propose_graph: iteration 33 ; core 0 of 2 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 34 ; core 0 of 1 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 35 ; core 0 of 4 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 36 ; core 0 of 4 ; original_cips tried  0 ; size 47
# _propose_graph: iteration 37 ; core 0 of 4 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 38 ; core 0 of 3 ; original_cips tried  0 ; size 43
# _propose_graph: iteration 39 ; core 0 of 1 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 40 ; core 0 of 2 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 41 ; core 0 of 14 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 42 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 43 ; core 0 of 22 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 44 ; core 0 of 14 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 45 ; core 0 of 6 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 46 ; core 0 of 14 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 47 ; core 0 of 22 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 48 ; core 0 of 1 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 49 ; core 0 of 14 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 50 ; core 0 of 22 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 51 ; core 0 of 22 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 52 ; core 0 of 5 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 53 ; core 0 of 14 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 54 ; core 0 of 1 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 55 ; core 0 of 22 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 56 ; core 0 of 1 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 57 ; core 0 of 3 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 58 ; core 0 of 14 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 59 ; core 0 of 14 ; original_cips tried  0 ; size 40
# _propose_graph: iteration 60 ; core 0 of 15 ; original_cips tried  0 ; size 44
# _propose_graph: iteration 61 ; core 0 of 2 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 62 ; core 0 of 2 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 63 ; core 0 of 2 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 64 ; core 0 of 3 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 65 ; core 0 of 15 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 66 ; core 0 of 15 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 67 ; core 0 of 2 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 68 ; core 0 of 15 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 69 ; core 0 of 3 ; original_cips tried  0 ; size 31
# _propose_graph: iteration 70 ; core 0 of 15 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 71 ; core 0 of 22 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 72 ; core 0 of 15 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 73 ; core 0 of 22 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 74 ; core 0 of 22 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 75 ; core 0 of 3 ; original_cips tried  0 ; size 33
# _propose_graph: iteration 76 ; core 0 of 1 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 77 ; core 0 of 3 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 78 ; core 0 of 1 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 79 ; core 0 of 1 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 80 ; core 0 of 3 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 81 ; core 0 of 3 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 82 ; core 0 of 15 ; original_cips tried  0 ; size 35
# _propose_graph: iteration 83 ; core 0 of 14 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 84 ; core 0 of 22 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 85 ; core 0 of 3 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 86 ; core 0 of 1 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 87 ; core 0 of 14 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 88 ; core 0 of 14 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 89 ; core 0 of 22 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 90 ; core 0 of 1 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 91 ; core 0 of 22 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 92 ; core 0 of 22 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 93 ; core 0 of 14 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 94 ; core 0 of 4 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 95 ; core 0 of 13 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 96 ; core 0 of 1 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 97 ; core 0 of 15 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 98 ; core 0 of 22 ; original_cips tried  0 ; size 37
# _propose_graph: iteration 99 ; core 0 of 14 ; original_cips tried  0 ; size 37
# Graph id: 22
# _propose_graph: iteration 0 ; core 0 of 14 ; original_cips tried  0 ; size 20
# _propose_graph: iteration 1 ; core 0 of 14 ; original_cips tried  0 ; size 13
# _propose_graph: iteration 2 ; core 0 of 14 ; original_cips tried  0 ; size 13
# _propose_graph: iteration 3 ; core 0 of 22 ; original_cips tried  0 ; size 24
# _propose_graph: iteration 4 ; core 0 of 14 ; original_cips tried  0 ; size 28
# _propose_graph: iteration 5 ; core 0 of 22 ; original_cips tried  0 ; size 13
# _propose_graph: iteration 6 ; core 0 of 4 ; original_cips tried  0 ; size 13
# _propose_graph: iteration 7 ; core 0 of 14 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 8 ; core 0 of 4 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 9 ; core 0 of 14 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 10 ; core 0 of 14 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 11 ; core 0 of 14 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 12 ; core 0 of 4 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 13 ; core 0 of 3 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 14 ; core 0 of 22 ; original_cips tried  0 ; size 15
# _propose_graph: iteration 15 ; core 0 of 3 ; original_cips tried  0 ; size 15
# _propose_graph: iteration 16 ; core 0 of 4 ; original_cips tried  0 ; size 19
# _propose_graph: iteration 17 ; core 0 of 4 ; original_cips tried  0 ; size 19
# _propose_graph: iteration 18 ; core 0 of 4 ; original_cips tried  0 ; size 21
# _propose_graph: iteration 19 ; core 0 of 22 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 20 ; core 0 of 4 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 21 ; core 0 of 4 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 22 ; core 0 of 22 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 23 ; core 0 of 4 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 24 ; core 0 of 22 ; original_cips tried  0 ; size 17
# _propose_graph: iteration 25 ; core 0 of 4 ; original_cips tried  0 ; size 28
# _propose_graph: iteration 26 ; core 0 of 4 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 27 ; core 0 of 4 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 28 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 29 ; core 0 of 5 ; original_cips tried  0 ; size 28
# _propose_graph: iteration 30 ; core 0 of 5 ; original_cips tried  0 ; size 28
# _propose_graph: iteration 31 ; core 0 of 5 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 32 ; core 0 of 3 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 33 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 34 ; core 0 of 3 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 35 ; core 0 of 1 ; original_cips tried  0 ; size 28
# _propose_graph: iteration 36 ; core 0 of 3 ; original_cips tried  0 ; size 28
# _propose_graph: iteration 37 ; core 0 of 22 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 38 ; core 0 of 22 ; original_cips tried  0 ; size 26
# _propose_graph: iteration 39 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 40 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 41 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 42 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 43 ; core 0 of 1 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 44 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 45 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 46 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 47 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 48 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 49 ; core 0 of 1 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 50 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 51 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 52 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 53 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 54 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 55 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 56 ; core 0 of 14 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 57 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 58 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 59 ; core 0 of 3 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 60 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 61 ; core 0 of 5 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 62 ; core 0 of 1 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 63 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 64 ; core 0 of 5 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 65 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 66 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 67 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 68 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 69 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 70 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 71 ; core 0 of 1 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 72 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 73 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 74 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 75 ; core 0 of 5 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 76 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 77 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 78 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 79 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 80 ; core 0 of 4 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 81 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 82 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 83 ; core 0 of 3 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 84 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 85 ; core 0 of 22 ; original_cips tried  0 ; size 30
# _propose_graph: iteration 86 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 87 ; core 0 of 3 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 88 ; core 0 of 3 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 89 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 90 ; core 0 of 5 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 91 ; core 0 of 3 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 92 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 93 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 94 ; core 0 of 4 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 95 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 96 ; core 0 of 22 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 97 ; core 0 of 3 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 98 ; core 0 of 4 ; original_cips tried  0 ; size 32
# _propose_graph: iteration 99 ; core 0 of 5 ; original_cips tried  0 ; size 32
# Graph id: 23
# CPU times: user 31.2 s, sys: 764 ms, total: 32 s
# Wall time: 32.8 s

# %% [markdown]
# ## show score history for each samplerun

# %%
# %matplotlib inline
from itertools import islice
import numpy as np
import matplotlib.pyplot as plt
step=1
num_graphs_per_plot=3
num_plots=np.ceil([len(scores)/num_graphs_per_plot])
for i in range(num_plots):
    plt.figure(figsize=(10,5))
    for j,score in enumerate(scores[i*num_graphs_per_plot:i*num_graphs_per_plot+num_graphs_per_plot]):
        data = list(islice(score,None, None, step))
        plt.plot(data, label='graph %d'%(j+i*num_graphs_per_plot+id_start))
    plt.legend(loc='lower right')
    plt.grid()
    plt.ylim(-0.1,1.1)
    plt.show()

# %% [markdown]
# ---
