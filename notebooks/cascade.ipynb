# %% [markdown]
# # Cascade
#
# learning layers of abstractions :)

# %% [markdown]
# #### initialise nb

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from eden.util import configure_logging
import logging

configure_logging(logging.getLogger(),verbosity=2)
from IPython.core.display import HTML
HTML('<style>.container { width:95% !important; }</style>')

# data source, see introduction for details.
from eden.converter.graph.gspan import gspan_to_eden
from itertools import islice
def get_graphs(dataset_fname='../toolsdata/bursi.pos.gspan', size=100):
    return islice(gspan_to_eden(dataset_fname),size)

# %%
# %%time
import graphlearn.minor.cascade as cascade
graphs=get_graphs(size=200)
mycascade=cascade.Cascade(depth=2,debug=True)
mycascade.fit_transform(graphs)
# Out:
# training transformer # 0
# minortransform fit. input after select layer
# Classifier:
# SGDClassifier(alpha=0.00056460729608897762, average=False, class_weight=None,
#        epsilon=0.1, eta0=0.11248684727792158, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='log', n_iter=70,
#        n_jobs=1, penalty='l1', power_t=0.3581757826186408,
#        random_state=None, shuffle=True, verbose=0, warm_start=False)
#
# Predictive performance:
#             accuracy: 1.000 +- 0.000
#            precision: 1.000 +- 0.000
#               recall: 1.000 +- 0.000
#                   f1: 1.000 +- 0.000
#    average_precision: 1.000 +- 0.000
#              roc_auc: 1.000 +- 0.000
# minortransform fit. this is what the subgraphs i got from the abstractor look like
# num clusters: 4
# class: 0 count:10 (0.42)
# class: 1 count:3 (0.12)
# class: 2 count:2 (0.08)
# class: 3 count:2 (0.08)
# class: 4 count:2 (0.08)
# class: -1 count:5 (0.21)
#
# ...

# %%
# %%time
from graphlearn.utils import draw
graphs = get_graphs(size=200)
mycascade = cascade.Cascade(depth=2,debug=False)
graphs = mycascade.fit_transform(graphs)
draw.graphlearn_layered(graphs[:5])
# Out:
# training transformer # 0
#
# Classifier:
# SGDClassifier(alpha=0.00091551394743735921, average=False, class_weight=None,
#        epsilon=0.1, eta0=0.025579507347107566, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='log', n_iter=80,
#        n_jobs=1, penalty='l2', power_t=0.40754003713001796,
#        random_state=None, shuffle=True, verbose=0, warm_start=False)
#
# Predictive performance:
#             accuracy: 1.000 +- 0.000
#            precision: 1.000 +- 0.000
#               recall: 1.000 +- 0.000
#                   f1: 1.000 +- 0.000
#    average_precision: 1.000 +- 0.000
#              roc_auc: 1.000 +- 0.000
# num clusters: 3
# class: 0 count:3 (0.17)
# class: 1 count:7 (0.39)
# class: 2 count:2 (0.11)
# class: 3 count:2 (0.11)
# class: -1 count:4 (0.22)
#
# training transformer # 1
#
# Classifier:
# SGDClassifier(alpha=0.00044676720102920336, average=False, class_weight=None,
# ...

# %% [markdown]
# -------------------------------
